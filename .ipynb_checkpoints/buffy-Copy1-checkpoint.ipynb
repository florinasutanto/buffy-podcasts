# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# setting spotify API credentials
client_id = 'cb3f2e1943d14f4f88da88de2124ee41'
client_secret = '0fc81353c44d409d833d034a74333ae5'

# authenticate and authorize application
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# define base url
base_url = 'https://api.spotify.com/v1/search?q=buffy+the+vampire+slayer&type=episode%2Cshow&market=US&limit=50&offset='

# list to store all data
all_data = []

# iterate through all the offsets (950)
for offset in range(0, 951):
    url = base_url + str(offset)
    response = sp._get(url)
    data = response
    all_data.append(data)

# specify file path for json file
file_path = 'spotify_data.json'

# open the file and write the data to the file
with open(file_path, 'w') as json_file:
    json.dump(all_data, json_file)

# confirmation message
print(f"Data saved to {file_path} successfully.")
# Out:
# Data saved to spotify_data.json successfully.

# %%
import json
import datetime
import pandas as pd

with open('spotify_data.json', 'r') as file:
    buffy = json.load(file)

# %%
print(buffy[0].keys())
print("--")
print(buffy[0]['shows'].keys())
print("--")
print(buffy[0]['shows']['items'][0].keys())
print("--")
print(buffy[0]['episodes']['items'][0]['name'])
print("--")
# print(buffy[0]['episodes']['items'][1])
# Out:
# dict_keys(['shows', 'episodes'])
# --
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])
# --
# dict_keys(['available_markets', 'copyrights', 'description', 'explicit', 'external_urls', 'href', 'html_description', 'id', 'images', 'is_externally_hosted', 'languages', 'media_type', 'name', 'publisher', 'total_episodes', 'type', 'uri'])
# --
# 1.01: Welcome to the Hellmouth
# --

# %% [markdown]
# # are people still talking about buffy? let's look at spotify podcasts
# ### remember to hide api keys

# %%
dates = []

for episode in buffy:
    for item in episode['episodes']['items']:
        date = item['release_date']
        date_obj = datetime.datetime.strptime(date, "%Y-%m-%d")
        dates.append(date_obj.strftime("%Y-%m-%d"))
    sorted_dates = sorted(dates)
    print(item['name']
# Out:
#   Cell In[122], line 9
#     print(episde[]
#          ^
# SyntaxError: '(' was never closed

# %%
episodes = set()

for episode in buffy:
    for item in episode['episodes']['items']:
        name = item['name']
        date = item['release_date']
        if not ('Harry Potter' in name or
                'Spider-Man' in name or
                'Ant-Man' in name or
                'Mandalorian' in name) and name not in episodes:
            episodes.add(name)
            print(f"{name}: {date}")
# Out:
# 1.01: Welcome to the Hellmouth: 2016-09-14
# Faith, Hope & Trick | 37: 2023-06-12
# Beauty and the Beasts | 38: 2023-06-19
# Anne | 35: 2023-05-29
# Dead Man’s Party | 36: 2023-06-05
# Becoming (Part 2) | 34: 2023-05-22
# Killed by Death | 30: 2023-04-24
# Becoming (Part 1) | 33: 2023-05-15
# Passion | 29: 2023-04-17
# Go Fish | 32: 2023-05-08
# Episode 375: Special Episode: Introducing The Rewatcher: Buffy the Vampire Slayer: 2022-10-07
# Bewitched, Bothered and Bewildered | 28: 2023-04-10
# I Only Have Eyes for You | 31: 2023-05-01
# Welcome to the Hellmouth | 1: 2022-10-03
# Halloween | 18: 2023-01-30
# Surprise | 25: 2023-03-20
# Lie To Me | 19: 2023-02-06
# Phases | 27: 2023-04-03
# Innocence | 26: 2023-03-27
# The Harvest | 2: 2022-10-03
# Witch | 3: 2022-10-10
# Bad Eggs | 24: 2023-03-13
# Never Kill a Boy on the First Date | 5: 2022-10-24
# Prophecy Girl | 12: 2022-12-12
# Ted | 23: 2023-03-06
# Another Buffy Podcast: 85
# Poorly Read Podcast - Season 3: Buffy the Vampire Slayer: 108
# Boys Watching Buffy: 95
# Becoming Buffy: 114
# Still Pretty, a Buffy the Vampire Slayer podcast: 172
# Prophecy Girls: A Buffy Rewatch Podcast: 128
# Beer with Buffy | A Buffy the Vampire Slayer Podcast: 148
# Buffy Gays: 72
# Once more with feeling, our Buffy the Vampire Slayer podcast.: 95
# Slayed! - The Buffyverse Revisited: 59
# Booze & Buffy: 179
# Buffy the Vampire Straya: 73
# Buffy Boys: 156
# Bothered & Bewildered: A Buffyverse Podcast: 34
# Buffy and the Art of Story: 123
# The Sunnydale Review: A Buffy the Vampire Slayer Podcast: 63
# Big Miss Stake: A Buffy Podcast: 19
# Buffy Speak: 139
# Unspoiled! Buffy the Vampire Slayer: 112
# The Chosen Two - A Buffy Rewatch: 22
# Buffy Virgin: 100
# How I Ripped Off Buffy The Vampire Slayer: 146
# Gym Was Cancelled: A Buffy Podcast: 39
# We Are The Gayers | A Buffy Podcast: 5
# Earp Meet Buffy: 31
# One Girl in All The World: A Buffy Rewatch Podcast: 9
# Buffy the Serial Podslayer: 266
# Tabula Rasa, B!tches!: A Buffy Rewatch Show: 33
# The Buffy Breakdown: 38
# Buffy: 6
# What's This Bitch Talking About? (a Buffy Podcast): 173
# Buffyverse and Converse: 15
# The Queer Buffy Podcast: 5
# ReVisiting Sunnydale: A Buffy Podcast: 139
# My Best Friend Thinks She's Buffy: 59
# Buffy Back Issue Bin: 89
# Buffy & Vampoddarna: 8
# A Buffy Fan and Sam: 28
# Does Buffy Suck?: 17
# Hush: A Buffy Podcast: 20
# Invite Me In: A Buffy Podcast: 12
# Beer Bad, Buffy Podcast Good: 9
# Get Slayed: A Buffy Podcast: 50
# Buffyverse: 2
# Getting Buff with Buffy: 2
# Buffy and the Lesbians: 11
# Into Every Generation a Slayer Is Born: How Buffy Staked Our Hearts: 29
# Buffy Boyfriends: 26
# Slayers & Vampires: The Complete Uncensored, Unauthorized Oral History of Buffy & Angel: 31

# %%
import csv

podcast = set()
field_names = ['Podcast Name', 'Description', 'Total Episodes', 'Explicit', 'URL', 'Image']

# Open the CSV file in write mode
with open('podcasts.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    
    writer.writerow(field_names)

    for show in buffy:
        for total in show['shows']['items']:
            name = total['name'].lower()
            url = url = total['external_urls']['spotify'].split(' ')[0]
            
            if total['explicit'] == True:
                explicit_status = "Yes"
            else:
                explicit_status = "No"
            
            if 'buffy' in name and name not in podcast:
                
                image_urls = []
                for image in total['images']:
                    image_url = image['url']
                    image_urls.append(image_url)
                if image_urls:
                    first_image_url = image_urls[0]
                else:
                    first_image_url = ""
                
                writer.writerow([total['name'], total['description'], total['total_episodes'], explicit_status, url, first_image_url])
                podcast.add(name)

print("CSV file created successfully.")


print(buffy[0]['shows']['items'][0]['images'][0]['url'])
# Out:
# CSV file created successfully.
# https://i.scdn.co/image/ab6765630000ba8a6874f79ca9ad5e7ddab78463

# %%
data = {'spotify': 'https://open.spotify.com/show/4jLKhdBDjkcUt7w84a6jKR'}

# Extract the URL part
url = data['spotify'].split(' ')[00]

print(url)
# Out:
# https://open.spotify.com/show/4jLKhdBDjkcUt7w84a6jKR
